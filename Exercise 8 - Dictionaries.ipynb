# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
from collections import OrderedDict



gpp_file ='C:\\Users\\pbwells\\Downloads\\data\\data\\orch_gpp_monthly_2007-2011.nc'
f=nc.Dataset(gpp_file, 'r')
dir(f)
# Out:
# ['CDI',
#  'CDO',
#  'Conventions',
#  'NCO',
#  'TimeStamp',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__orthogonal_indexing__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '_close',
#  '_close_mem',
#  '_enddef',
#  '_grpid',
#  '_isopen',
#  '_ncstring_attrs__',
#  '_redef',
#  'close',
#  'cmptypes',
#  'createCompoundType',
#  'createDimension',
#  'createEnumType',
#  'createGroup',
#  'createVLType',
#  'createVariable',
#  'data_model',
#  'delncattr',
#  'dimensions',
#  'disk_format',
#  'enumtypes',
#  'file_format',
#  'file_name',
#  'filepath',
#  'get_variables_by_attributes',
#  'getncattr',
# ...

# %%
var_info=f.variables
print(var_info)
# Out:
# OrderedDict([('GPP', <class 'netCDF4._netCDF4.Variable'>
# float64 GPP(time, lat, lon)
#     standard_name: Total (over all PFTs) Net Assimilation
#     long_name: Total (over all PFTs) Net Assimilation
#     units: gC/m^2/s
#     _FillValue: 9.969209968386869e+36
#     online_operation: ave(scatter(X*0.000556))
#     interval_operation: 1800.0
#     interval_write: 86400.0
# unlimited dimensions: time
# current shape = (60, 90, 180)
# filling on), ('lat', <class 'netCDF4._netCDF4.Variable'>
# float32 lat(lat)
#     standard_name: latitude
#     long_name: Latitude
#     units: degrees_north
#     axis: Y
# unlimited dimensions:
# current shape = (90,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# ), ('lon', <class 'netCDF4._netCDF4.Variable'>
# float32 lon(lon)
#     standard_name: longitude
#     long_name: Longitude
#     units: degrees_east
#     axis: X
# unlimited dimensions:
# current shape = (180,)
# ...

# %%
# extract information from dimensions - examples
dim_info = f.dimensions
print(dim_info)
# Out:
# OrderedDict([('time', <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 60
# ), ('lat', <class 'netCDF4._netCDF4.Dimension'>: name = 'lat', size = 90
# ), ('lon', <class 'netCDF4._netCDF4.Dimension'>: name = 'lon', size = 180
# )])

# %%
dim_names=f.dimensions.keys()
print(dim_names)
# Out:
# odict_keys(['time', 'lat', 'lon'])

# %%
dim_values=[f.dimensions[d].__len__() for d in dim_names]
print(dim_values)
# Out:
# [60, 90, 180]

# %%
# define GPP

print(f.variables['GPP'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 GPP(time, lat, lon)
#     standard_name: Total (over all PFTs) Net Assimilation
#     long_name: Total (over all PFTs) Net Assimilation
#     units: gC/m^2/s
#     _FillValue: 9.969209968386869e+36
#     online_operation: ave(scatter(X*0.000556))
#     interval_operation: 1800.0
#     interval_write: 86400.0
# unlimited dimensions: time
# current shape = (60, 90, 180)
# filling on

# %%
gpp_var = 'GPP'
gpp_data = f.variables[gpp_var][:]
f.close()

# %%
print(np.shape(gpp_data))
# Out:
# (60, 90, 180)

# %%
plt.imshow(gpp_data[0,:,:])
plt.title('Monthly GPP Data - January (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[1,:,:])
plt.title('Monthly GPP Data - February (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[2,:,:])
plt.title('Monthly GPP Data - March (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[3,:,:])
plt.title('Monthly GPP Data - April (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[4,:,:])
plt.title('Monthly GPP Data - May (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[5,:,:])
plt.title('Monthly GPP Data - June (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[6,:,:])
plt.title('Monthly GPP Data - July (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[7,:,:])
plt.title('Monthly GPP Data - August (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[8,:,:])
plt.title('Monthly GPP Data - September (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[9,:,:])
plt.title('Monthly GPP Data - October (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[10,:,:])
plt.title('Monthly GPP Data - November (2007-2011)')
plt.show()

# %%
# plot map for each month
plt.imshow(gpp_data[11,:,:])
plt.title('Monthly GPP Data - December (2007-2011)')
plt.show()

# %%
# Create a new variable with total GPP over time
new_f = nc.Dataset('total')

# %%
gpp_data_filled = np.ma.filled(gpp_data)
print(gpp_data_filled)
# Out:
# [[[9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   [9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   [9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   ...
#   [9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   [9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   [9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]]
#
#  [[9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   [9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   [9.96920997e+36 9.96920997e+36 9.96920997e+36 ... 9.96920997e+36
#    9.96920997e+36 9.96920997e+36]
#   ...
# ...

# %%
plt.imshow(gpp_data_filled[0,:,:])
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
masked_gpp = np.ma.masked_where(gpp_data_filled > 20, gpp_data_filled)
print(masked_gpp)
# Out:
# [[[-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   ...
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]]
#
#  [[-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   ...
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]]
#
#  [[-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   ...
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]]
#
#  ...
#
#  [[-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   ...
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]]
#
#  [[-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   ...
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]]
#
#  [[-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   [-- -- -- ... -- -- --]
#   ...
# ...
